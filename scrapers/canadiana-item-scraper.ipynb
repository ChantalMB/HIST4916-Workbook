# %% [markdown]
# # Accessing the Pages of "[Domestic Science Recipes](https://www.canadiana.ca/view/oocihm.95242/1?r=0&s=1)"
# ### aka A Scraper that works on [Canadiana Online](https://www.canadiana.ca/)

# %%
# %pip install beautifulsoup4
# %pip install wget

# might need this if you use macOS
# %pip install lxml

# %% [markdown]
# Grab the HTML of the first page of your source.

# %%
import requests

# target webpage
url = "https://www.canadiana.ca/view/oocihm.95242/11?r=0&s=1"

response = requests.get(url)
data = response.text
 
from bs4 import BeautifulSoup
import lxml

soup = BeautifulSoup(data, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="vh-100" id="html" lang="en">
#  <head>
#   <title>
#    Search results for cookery - Canadiana Online
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Canadiana" name="author"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto&amp;display=swap" rel="stylesheet"/>
#   <link href="https://www.canadiana.ca/static/css/online.css?cssr=3" rel="stylesheet"/>
#   <link href="https://www.canadiana.ca/static/images/icons/32.png" rel="icon" sizes="32x32"/>
#   <link href="https://www.canadiana.ca/static/images/icons/128.png" rel="icon" sizes="128x128"/>
#   <link href="https://www.canadiana.ca/static/images/icons/192.png" rel="icon" sizes="192x192"/>
#   <link href="https://www.canadiana.ca/static/images/icons/196.png" rel="shortcut icon" sizes="196x196"/>
#   <link href="https://www.canadiana.ca/static/images/icons/152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://www.canadiana.ca/static/images/icons/180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <meta content="#1d808b" name="theme-color"/>
#  </head>
#  <body class="d-flex flex-column vh-100 action-search-index">
#   <a href="#main" id="skipLink">
#    Skip to main content
#   </a>
#   <header>
#    <div class="container">
#     <div class="row py-3">
#      <h1 class="header-title">
#       <a href="https://www.canadiana.ca/">
#        <img alt="Canadiana Online" id="headerTitle" src="/static/images/canadiana-tag-color.svg"/>
#       </a>
#      </h1>
#      <div class="header-button">
#       <button class="btn btn-lg btn-icon menu-open">
#       </button>
#       <button class="btn btn-lg btn-primary menu-close">
#        X
#       </button>
#      </div>
#      <nav class="header-links">
#       <ul class="small-links">
#        <li>
#         <a href="http://www.canadiana.ca/terms">
#          Terms of Service
#         </a>
#        </li>
#        <li>
#         <b>
#          English
#         </b>
#         |
#         <a href="https://www.canadiana.ca/search/general/1?collection=monog&amp;df=&amp;dt=&amp;lang=eng&amp;q0.0=cookery&amp;usrlang=fr">
#          Français
#         </a>
#        </li>
#        <li>
#         <a class="sm-icon facebook" href="https://www.facebook.com/CRKNRCDR/">
#          <span class="sr-only">
#           Facebook
#          </span>
#         </a>
#         <a class="sm-icon twitter" href="https://twitter.com/CRKN_RCDR">
#          <span class="sr-only">
#           Twitter
#          </span>
#         </a>
#         <a class="sm-icon linkedin" href="https://www.linkedin.com/mwlite/company/canadian-research-knowledge-network">
#          <span class="sr-only">
#           LinkedIn
#          </span>
#         </a>
#        </li>
#       </ul>
#       <ul class="large-links">
#        <li>
#         <a href="https://www.crkn-rcdr.ca/en/heritage-content">
#          About
#         </a>
#        </li>
#        <li>
#         <a href="//heritage.canadiana.ca/">
#          Héritage
#         </a>
#        </li>
#        <li>
#         <a href="https://www.crkn-rcdr.ca/en">
#          CRKN
#         </a>
#        </li>
#        <li>
#         <a href="https://www.crkn-rcdr.ca/en/contact-us">
#          Contact Us
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#   </header>
#   <main class="flex-grow-1" id="main" role="main">
#    <div class="container-md">
#     <div class="row">
#      <div class="col-md-4 col-lg-3">
#       <aside role="search">
#        <form action="https://www.canadiana.ca/search/post" method="POST">
#         <label for="query">
#          Refine your search
#         </label>
#         <input class="form-control form-control-lg" id="query" name="q" type="text" value="cookery"/>
#         <div class="form-group form-check mt-3">
#          <input checked="" class="form-check-input" id="handlerCheck" name="include_issues" type="checkbox"/>
#          <label class="form-check-label" for="handlerCheck">
#           Include results from individual issues
#          </label>
#         </div>
#         <div class="form-group mt-3">
#          <label for="fieldSelect">
#           Search in
#          </label>
#          <select class="custom-select" id="fieldSelect" name="field">
#           <option value="">
#            Everything
#           </option>
#           <option value="ti">
#            Titles
#           </option>
#           <option value="au">
#            Creator Names
#           </option>
#           <option value="su">
#            Subjects
#           </option>
#           <option value="tx">
#            Text
#           </option>
#          </select>
#         </div>
#         <div class="collapse-pane">
#          <div aria-controls="cp_sort" aria-expanded="true" class="collapse-pane-header" data-target="#cp_sort" data-toggle="collapse" role="button" tabindex="0">
#           <span>
#            Sort Order
#           </span>
#          </div>
#          <div class="collapse-pane-content collapse show" id="cp_sort">
#           <input name="so" type="hidden" value="score"/>
#           <div class="list-group list-group-flush">
#            <a class="list-group-item list-group-item-action active" href="https://www.canadiana.ca/search?dt=&amp;collection=monog&amp;so=score&amp;q0.0=cookery&amp;df=&amp;lang=eng">
#             relevance
#            </a>
#            <a class="list-group-item list-group-item-action" href="https://www.canadiana.ca/search?dt=&amp;collection=monog&amp;so=newest&amp;q0.0=cookery&amp;df=&amp;lang=eng">
#             newest
#            </a>
#            <a class="list-group-item list-group-item-action" href="https://www.canadiana.ca/search?lang=eng&amp;df=&amp;q0.0=cookery&amp;so=oldest&amp;collection=monog&amp;dt=">
#             oldest
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="collapse-pane">
#          <div aria-controls="cp_daterange" aria-expanded="true" class="collapse-pane-header" data-target="#cp_daterange" data-toggle="collapse" role="button" tabindex="0">
#           <span>
#            Date Range:
#           </span>
#          </div>
#          <div class="collapse-pane-content collapse show" id="cp_daterange">
#           <div class="form-row">
#            <div class="col">
#             <label for="dateRangeFrom">
#              from
#             </label>
#             <input class="form-control" id="dateRangeFrom" maxlength="4" name="df" placeholder="1609" type="text" value=""/>
#            </div>
#            <div class="col">
#             <label for="dateRangeTo">
#              to
#             </label>
#             <input class="form-control" id="dateRangeTo" maxlength="4" name="dt" placeholder="2018" type="text" value=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="collapse-pane">
#          <div aria-controls="cp_lang" aria-expanded="true" class="collapse-pane-header" data-target="#cp_lang" data-toggle="collapse" role="button" tabindex="0">
#           <span>
#            Language
#           </span>
#          </div>
#          <div class="collapse-pane-content collapse show" id="cp_lang">
#           <div class="form-check">
#            <input checked="" class="form-check-input" id="facetlangeng" name="lang" type="checkbox" value="eng"/>
#            <label class="form-check-label" for="facetlangeng">
#             English (2754)
#            </label>
#           </div>
#           <div class="form-check">
#            <input class="form-check-input" id="facetlangfra" name="lang" type="checkbox" value="fra"/>
#            <label class="form-check-label" for="facetlangfra">
#             French (53)
#            </label>
#           </div>
#           <div class="form-check">
#            <input class="form-check-input" id="facetlangdeu" name="lang" type="checkbox" value="deu"/>
#            <label class="form-check-label" for="facetlangdeu">
#             German (2)
#            </label>
#           </div>
#           <div class="form-check">
#            <input class="form-check-input" id="facetlangita" name="lang" type="checkbox" value="ita"/>
#            <label class="form-check-label" for="facetlangita">
#             Italian (2)
#            </label>
#           </div>
#           <div class="form-check">
#            <input class="form-check-input" id="facetlanglat" name="lang" type="checkbox" value="lat"/>
#            <label class="form-check-label" for="facetlanglat">
#             Latin (2)
#            </label>
#           </div>
#           <div class="form-check">
#            <input class="form-check-input" id="facetlangoji" name="lang" type="checkbox" value="oji"/>
#            <label class="form-check-label" for="facetlangoji">
#             Ojibwa (2)
#            </label>
#           </div>
#           <div class="form-check">
#            <input class="form-check-input" id="facetlangang" name="lang" type="checkbox" value="ang"/>
#            <label class="form-check-label" for="facetlangang">
#             English, Old (ca.450-1100) (1)
#            </label>
#           </div>
#           <div class="form-check">
#            <input class="form-check-input" id="facetlangdan" name="lang" type="checkbox" value="dan"/>
#            <label class="form-check-label" for="facetlangdan">
#             Danish (1)
#            </label>
#           </div>
#           <div class="form-check">
#            <input class="form-check-input" id="facetlangrus" name="lang" type="checkbox" value="rus"/>
#            <label class="form-check-label" for="facetlangrus">
#             Russian (1)
#            </label>
#           </div>
#          </div>
#         </div>
#         <div class="collapse-pane">
#          <div aria-controls="cp_collection" aria-expanded="true" class="collapse-pane-header" data-target="#cp_collection" data-toggle="collapse" role="button" tabindex="0">
#           <span>
#            Collection
#           </span>
#          </div>
#          <div class="collapse-pane-content collapse show" id="cp_collection">
#           <div class="form-check">
#            <input class="form-check-input" id="facetcollectionserials" name="collection" type="checkbox" value="serials"/>
#            <label class="form-check-label" for="facetcollectionserials">
#             Serials: Periodicals, Annuals and Newspapers (4107)
#            </label>
#           </div>
#           <div class="form-check">
#            <input checked="" class="form-check-input" id="facetcollectionmonog" name="collection" type="checkbox" value="monog"/>
#            <label class="form-check-label" for="facetcollectionmonog">
#             Monographs (2754)
#            </label>
#           </div>
#           <div class="form-check">
#            <input class="form-check-input" id="facetcollectiongovpubs" name="collection" type="checkbox" value="govpubs"/>
#            <label class="form-check-label" for="facetcollectiongovpubs">
#             Government Publications (72)
#            </label>
#           </div>
#          </div>
#         </div>
#         <div class="mt-3 mb-3 btn-group">
#          <button class="btn btn-lg btn-primary" type="submit" value="submit">
#           Search
#          </button>
#          <a class="btn btn-lg btn-outline-secondary" href="/search-tips">
#           Help
#          </a>
#         </div>
#        </form>
#       </aside>
#      </div>
#      <div class="col-md-8 col-lg-9">
#       <h2>
#        2,754 results
#               for
#        <i>
#         cookery
#        </i>
#        .
#       </h2>
#       <p>
#        Showing results 1 - 10.
#       </p>
#       <nav aria-label="Navigate search results">
#        <ul class="pagination">
#         <li class="page-item active">
#          <a class="page-link">
#           1
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://www.canadiana.ca/search/general/2?collection=monog&amp;dt=&amp;lang=eng&amp;df=&amp;q0.0=cookery">
#           2
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://www.canadiana.ca/search/general/3?collection=monog&amp;dt=&amp;lang=eng&amp;df=&amp;q0.0=cookery">
#           3
#          </a>
#         </li>
#         <li class="page-item disabled">
#          <a class="page-link">
#           ...
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://www.canadiana.ca/search/general/276?collection=monog&amp;dt=&amp;lang=eng&amp;df=&amp;q0.0=cookery">
#           276
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://www.canadiana.ca/search/general/2?collection=monog&amp;dt=&amp;lang=eng&amp;df=&amp;q0.0=cookery">
#           Next
#          </a>
#         </li>
#        </ul>
#       </nav>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_1" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_1" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.9_90234">
#          Food and cookery  / by H.S. Anderson
#         </a>
#        </h3>
#        <p>
#         Calgary : Pacific Press Pub. Association, c1917.; 164 pages, 163 with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.9_90234" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_1">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Creator
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=au%3A%22Anderson%2C+H.+S.+(Hans+Steele)%2C+b.+1877%22">
#             Anderson, H. S. (Hans Steele), b. 1877
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            Food and cookery / by H.S. Anderson
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            Calgary : Pacific Press Pub. Association, c1917.
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            9_90234
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cookery%22">
#             Cookery
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine%22">
#             Cuisine
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            Agriculture Canada, Canadian Agriculture Library, Ottawa
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            Description
#           </dt>
#           <dd class="col-md-9">
#            163 p. ; 19 cm.
#            <br/>
#            Includes index.
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.9_90234">
#             https://www.canadiana.ca/view/oocihm.9_90234
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <hr/>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_2" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_2" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.87619">
#          British, French, Italian, Russian, Belgian cookery
#         </a>
#        </h3>
#        <p>
#         [Montréal?] : publisher not identified, ©1916; 40 pages with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.87619" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_2">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            British, French, Italian, Russian, Belgian cookery
#            <br/>
#            Allied cookery
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            [Montréal?] : publisher not identified, ©1916
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            87619
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cooking%22">
#             Cooking
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine%22">
#             Cuisine
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            University of Toronto, Thomas Fisher Rare Book Library
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            Description
#           </dt>
#           <dd class="col-md-9">
#            38 pages ; 22 cm.
#            <br/>
#            Cover title.
#            <br/>
#            Complete ed. (New York, 1916) has title: Allied cookery.
#            <br/>
#            "To aid the war sufferers in the devastated districts of France."
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.87619">
#             https://www.canadiana.ca/view/oocihm.87619
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <hr/>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_3" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_3" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.12438">
#          Cookery / by Amy G. Richards.
#         </a>
#        </h3>
#        <p>
#         Montréal : E.M. Renouf, 1895.; 457 pages, 447 with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.12438" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_3">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Creator
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=au%3A%22Richards%2C+Amy+G.%22">
#             Richards, Amy G.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            Cookery
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            Montréal : E.M. Renouf, 1895.
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            12438
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cookery.%22">
#             Cookery.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine.%22">
#             Cuisine.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            Scanned from a CIHM microfiche of the original publication held by the National Library of Canada.
#           </dd>
#           <dt class="col-md-3">
#            Notes
#           </dt>
#           <dd class="col-md-9">
#            "But for life the universe were nothing ... Brillat-Savarin."
#            <br/>
#            Includes glossary.
#            <br/>
#            Title from title screen.
#            <br/>
#            Includes index.
#            <br/>
#            436 p. ; 19 cm.
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#            <br/>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.12438">
#             https://www.canadiana.ca/view/oocihm.12438
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <hr/>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_4" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_4" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.990031">
#          The one maid book of cookery
#         </a>
#        </h3>
#        <p>
#         Toronto : Bell &amp; Cockburn, 1913.; 237 pages, 234 with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.990031" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_4">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Creator
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=au%3A%22Congreve%2C+A.+E.%22">
#             Congreve, A. E.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            The one maid book of cookery
#            <br/>
#            CIHM/ICMH microfiche series ; no. 9-90031
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            Toronto : Bell &amp; Cockburn, 1913.
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            990031
#            <br/>
#            FC 02 0203 no. 9-90031
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cookery.%22">
#             Cookery.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine.%22">
#             Cuisine.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            Filmed from a copy of the original publication held by the National Library of Canada.
#           </dd>
#           <dt class="col-md-3">
#            Notes
#           </dt>
#           <dd class="col-md-9">
#            3 microfiche (123 fr.)
#            <br/>
#            Includes index.
#            <br/>
#            217, [7] p. ; 20 cm.
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#            <br/>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.990031">
#             https://www.canadiana.ca/view/oocihm.990031
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <hr/>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_5" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_5" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.9_92245">
#          War-time cookery  / compiled by the St. Lawrence Chapter, I.O.D.E., Cornwall, Ont.
#         </a>
#        </h3>
#        <p>
#         Cornwall, Ont. : Press of the Freeholder, 1918.; 80 pages, 79 with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.9_92245" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_5">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Creator
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=au%3A%22Imperial+Order+Daughters+of+the+Empire.+St.+Lawrence+Chapter+(Cornwall%2C+Ont.)%22">
#             Imperial Order Daughters of the Empire. St. Lawrence Chapter (Cornwall, Ont.)
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            War-time cookery / compiled by the St. Lawrence Chapter, I.O.D.E., Cornwall, Ont.
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            Cornwall, Ont. : Press of the Freeholder, 1918.
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            9_92245
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cookery%22">
#             Cookery
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine%22">
#             Cuisine
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            Library and Archives Canada
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            Description
#           </dt>
#           <dd class="col-md-9">
#            74, [1] p. ; 23 cm.
#            <br/>
#            Reference: Driver.
#            <br/>
#            Includes advertising matter.
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.9_92245">
#             https://www.canadiana.ca/view/oocihm.9_92245
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <hr/>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_6" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_6" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.04164">
#          Cookery for the million
#         </a>
#        </h3>
#        <p>
#         Montreal : W. Drysdale, 1877.; 59 pages, 54 with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.04164" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_6">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            Cookery for the million : with useful hints to housewives.
#            <br/>
#            CIHM/ICMH microfiche series ; no. 04164
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            Montreal : W. Drysdale, 1877.
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            04164
#            <br/>
#            FC 02 0203 no. 04164
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cookery.%22">
#             Cookery.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine.%22">
#             Cuisine.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            Filmed from a copy of the original publication held by the Bibliothèque nationale du Québec.
#           </dd>
#           <dt class="col-md-3">
#            Notes
#           </dt>
#           <dd class="col-md-9">
#            1 microfiche (30 fr.).
#            <br/>
#            At head of title: A book for the times : how to live cheaply and well.
#            <br/>
#            47 p.
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#            <br/>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.04164">
#             https://www.canadiana.ca/view/oocihm.04164
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <hr/>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_7" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_7" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.01604">
#          Gems of fancy cookery : a collection of reliable and useful household recipes.
#         </a>
#        </h3>
#        <p>
#         Goderich, Ont. : F. Jordan, [1890?]; 49 pages with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.01604" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_7">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            Gems of fancy cookery : a collection of reliable and useful household recipes.
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            Goderich, Ont. : F. Jordan, [1890?]
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            01604
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cookery.%22">
#             Cookery.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine.%22">
#             Cuisine.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            Scanned from a CIHM microfiche of the original publication held by the Thomas Fisher Rare Book Library, University of Toronto Library.
#           </dd>
#           <dt class="col-md-3">
#            Notes
#           </dt>
#           <dd class="col-md-9">
#            Cover title.
#            <br/>
#            Includes advertising for F. Jordan, chemist &amp; druggist, Goderich, Ontario.
#            <br/>
#            Title from title screen.
#            <br/>
#            48 p. ; 17 cm.
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#            <br/>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.01604">
#             https://www.canadiana.ca/view/oocihm.01604
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <hr/>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_8" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_8" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.91705">
#          Household recipes, or, Domestic cookery
#         </a>
#        </h3>
#        <p>
#         [Montréal? : s.n.], 1865 (Montreal : A.A. Stevenson); 95 pages, 93 with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.91705" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_8">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Creator
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=au%3A%22Hart%2C+Constance+Hatton.%22">
#             Hart, Constance Hatton.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            Household recipes, or, Domestic cookery
#            <br/>
#            CIHM/ICMH microfiche series ; no. 91705
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            [Montréal? : s.n.], 1865 (Montreal : A.A. Stevenson)
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            91705
#            <br/>
#            FC 02 0203 no. 91705
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cookery.%22">
#             Cookery.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cooking%2C+Canadian%22">
#             Cooking, Canadian
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine.%22">
#             Cuisine.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine+canadienne.%22">
#             Cuisine canadienne.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            Filmed from a copy of the original publication held by the National Library of Canada.
#           </dd>
#           <dt class="col-md-3">
#            Notes
#           </dt>
#           <dd class="col-md-9">
#            1 microfiche (49 fr.)
#            <br/>
#            81, ix p. ; 17 cm.
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#            <br/>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.91705">
#             https://www.canadiana.ca/view/oocihm.91705
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <hr/>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_9" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_9" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.95275">
#          The new temperance cookery book
#         </a>
#        </h3>
#        <p>
#         Vancouver : Thomson Stationery Co., [1890?]; 353 pages, 345 with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.95275" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_9">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Creator
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=au%3A%22Gillette%2C+Fanny+Lea.%22">
#             Gillette, Fanny Lea.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            The new temperance cookery book
#            <br/>
#            CIHM/ICMH microfiche series ; no. 95275
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            Vancouver : Thomson Stationery Co., [1890?]
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            95275
#            <br/>
#            FC 02 0203 no. 95275
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cookery.%22">
#             Cookery.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine.%22">
#             Cuisine.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            Filmed from a copy of the original publication held by the British Columbia Archives and Records Service, Victoria.
#           </dd>
#           <dt class="col-md-3">
#            Notes
#           </dt>
#           <dd class="col-md-9">
#            4 microfiches (180 fr.) : ill.
#            <br/>
#            Driver.
#            <br/>
#            337 p. : ill. ; 19 cm.
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#            <br/>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.95275">
#             https://www.canadiana.ca/view/oocihm.95275
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <hr/>
#       <section class="search-item">
#        <h3>
#         <button aria-controls="dr_10" aria-expanded="false" class="btn btn-primary float-right ml-3 plus-minus" data-target="#dr_10" data-toggle="collapse" title="More about this item">
#          +
#         </button>
#         <a href="https://www.canadiana.ca/view/oocihm.01114">
#          Mrs. Clarke's cookery book
#         </a>
#        </h3>
#        <p>
#         Toronto : Grip, [1883?]; 415 pages, 405 with full-text search
#         <button class="btn btn-icon btn-sm help text-aligned" data-placement="right" data-toggle="tooltip" title="Canadiana uses OCR (optical character recognition) to provide full-text search for printed documents.">
#          <span class="sr-only">
#           Help
#          </span>
#         </button>
#        </p>
#        <p class="matching-pages" data-pkey="oocihm.01114" data-query="cookery">
#         <span class="matching-pages-results">
#         </span>
#         <span class="matching-pages-searching" style="display: none;">
#          Searching for matching pages...
#          <img alt="" class="loader" src="/static/images/loader.gif"/>
#         </span>
#        </p>
#        <div class="collapse" id="dr_10">
#         <div class="card">
#          <h4 class="card-header">
#           Document Record
#          </h4>
#          <dl class="row px-4 py-3 mb-0">
#           <dt class="col-md-3">
#            Creator
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=au%3A%22Clarke%2C+Anne%22">
#             Clarke, Anne
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Title
#           </dt>
#           <dd class="col-md-9">
#            Mrs. Clarke's cookery book : comprising a collection of about fourteen hundred practical, useful and unique receipts : including " sick room cookery" and a number of excellent receipts entitled "The Doctor" : also what to name the baby, a complete dictionary of Christian names, their origin and signification.
#            <br/>
#            CIHM/ICMH microfiche series ; no. 01114
#           </dd>
#           <dt class="col-md-3">
#            Published
#           </dt>
#           <dd class="col-md-9">
#            Toronto : Grip, [1883?]
#           </dd>
#           <dt class="col-md-3">
#            Identifier
#           </dt>
#           <dd class="col-md-9">
#            01114
#            <br/>
#            FC 02 0203 no. 01114
#           </dd>
#           <dt class="col-md-3">
#            Subject
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cookery.%22">
#             Cookery.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Medicine%2C+Popular.%22">
#             Medicine, Popular.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Names%2C+Personal.%22">
#             Names, Personal.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Cuisine.%22">
#             Cuisine.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22M%C3%A9decine+--+Ouvrages+de+vulgarisation.%22">
#             Médecine -- Ouvrages de vulgarisation.
#            </a>
#            <br/>
#            <a href="https://www.canadiana.ca/search?q0.0=su%3A%22Noms+de+personnes.%22">
#             Noms de personnes.
#            </a>
#           </dd>
#           <dt class="col-md-3">
#            Document source
#           </dt>
#           <dd class="col-md-9">
#            Filmed from a copy of the original publication held by the Metropolitan Toronto Library, Science &amp; Technology Department.
#           </dd>
#           <dt class="col-md-3">
#            Notes
#           </dt>
#           <dd class="col-md-9">
#            5 microfiches (210 fr.).
#            <br/>
#            Includes index.
#            <br/>
#            402 p.
#           </dd>
#           <dt class="col-md-3">
#            Collection
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/search?collection=monog">
#             Monographs
#            </a>
#            <br/>
#           </dd>
#           <dt class="col-md-3">
#            Language
#           </dt>
#           <dd class="col-md-9">
#            English
#           </dd>
#           <dt class="col-md-3">
#            Depositor
#           </dt>
#           <dd class="col-md-9">
#            Canadiana.org
#           </dd>
#           <dt class="col-md-3">
#            URL
#           </dt>
#           <dd class="col-md-9">
#            <a href="https://www.canadiana.ca/view/oocihm.01114">
#             https://www.canadiana.ca/view/oocihm.01114
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </section>
#       <nav aria-label="Navigate search results, again">
#        <ul class="pagination">
#         <li class="page-item active">
#          <a class="page-link">
#           1
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://www.canadiana.ca/search/general/2?collection=monog&amp;dt=&amp;lang=eng&amp;df=&amp;q0.0=cookery">
#           2
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://www.canadiana.ca/search/general/3?collection=monog&amp;dt=&amp;lang=eng&amp;df=&amp;q0.0=cookery">
#           3
#          </a>
#         </li>
#         <li class="page-item disabled">
#          <a class="page-link">
#           ...
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://www.canadiana.ca/search/general/276?collection=monog&amp;dt=&amp;lang=eng&amp;df=&amp;q0.0=cookery">
#           276
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://www.canadiana.ca/search/general/2?collection=monog&amp;dt=&amp;lang=eng&amp;df=&amp;q0.0=cookery">
#           Next
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </main>
#   <footer class="mt-auto bg-dark text-white">
#    <div class="container-lg">
#     <div class="row py-3 small">
#      <p class="col-lg text-center text-lg-left">
#       <a href="http://www.canadiana.ca/?usrlang=en">
#        <img alt="Canadiana" height="50" src="/static/images/canadiana-logo-inverted.svg"/>
#       </a>
#      </p>
#      <p class="col-lg-5 text-center">
#       <a href="http://www.canadiana.ca/terms">
#        Terms of Service
#       </a>
#       <br/>
#       © 2021 Canadian Research Knowledge Network
#       <a href="https://www.crkn-rcdr.ca/en/contact-us">
#        <img alt="Contact Us" src="/static/images/interface/phone.svg"/>
#       </a>
#      </p>
#      <p class="col-lg text-center text-lg-right">
#       <a class="d-inline-block" href="https://www.crkn-rcdr.ca/en">
#        <img alt="Canadian Research Knowledge Network" height="50" src="/static/images/crkn-logo-inverted.svg"/>
#       </a>
#       <a class="d-inline-block ml-3" href="https://www.cndhi-ipnpc.ca/en">
#        <img alt="CNDHI: Canadian National Digital Heritage Index" height="50" src="/static/images/cndhi-logo-inverted.svg"/>
#       </a>
#      </p>
#     </div>
#    </div>
#   </footer>
#   <div aria-hidden="true" id="imageCache">
#   </div>
#   <!--[if lte IE 9]>
#     <div id="noFlexWarning" aria-hidden="true">
#       <h2>Your browser may not be supported. Please consider downloading a more modern browser.</h2>
#       <ul>
#         <li><a href="https://www.mozilla.org/en-CA/firefox/new/">Mozilla Firefox</a></li>
#         <li><a href-"https://www.google.com/chrome/">Google Chrome</a></li>
#         <li><a href="https://www.microsoft.com/en-us/edge">Microsoft Edge</a></li>
#       </ul>
#     </div>
# ![endif]-->
#   <script src="https://www.canadiana.ca/static/js/cap.js?r=3" type="text/javascript">
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-162937182-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'UA-162937182-1');
#   </script>
#  </body>
# </html>

# %% [markdown]
# Now, list everything marked with the `img` tag to locate the actual image source.

# %%
# the 'option' tag is present for each image bc of the dropdown navigation
# find number of images there are in source by counting 'option' tag 
pgCount = soup.find_all('option')
print(len(pgCount))

imgs = soup.find_all('img')

# figure out id of img src
for img in imgs:
    print(img)

# %% [markdown]
# This step is technically skipable-- you could just copy the url from the list above-- but this makes it easier to c/p without error.

# %%
# grab src attribute
srcImg = soup.find_all(id='pvImg')

for url in srcImg:
    print(url['src'])

# %% [markdown]
# Here, you create a text file that's just a lists of all the image source urls. It's used in the following code cell where you run a `wget` command that downloads all of the pages from the document.

# %%
f = open("DSRpages.txt", "w")

i = 1

while i < 210:
    srcURL= 'https://image-tor.canadiana.ca/iiif/2/oocihm.95242%2Fdata%2Fsip%2Fdata%2Ffiles%2Foocihm.95242.'+ str(i) + '.jp2/full/!800,800/0/default.jpg?token=eyJhbGciOiJIUzI1NiJ9.eyJpYXQiOjE2MTI3NDk1MzgsImlzcyI6IkNBUCIsImV4cCI6MTYxMjgzNTkzOCwiZGVyaXZhdGl2ZUZpbGVzIjoib29jaWhtLjk1MjQyXFwvZGF0YVxcL3NpcFxcL2RhdGFcXC9maWxlc1xcLy4rXFwuKGpwZ3xqcDJ8dGlmKSJ9.IIDCVXcy753LDf3fQJts6XuIcHeHlwhwcoqlGlCk_SQ'
    print(srcURL)
    i = i + 1
    f.write(srcURL + '\n')
    
f.close()

# %%
# !wget --content-disposition -i DSRpages.txt -r --no-parent -nd -w 2 --limit-rate=100k
